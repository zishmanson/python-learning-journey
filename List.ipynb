# %%
n = 5

# %%
print(n)
# Out:
# 5

# %%
listA = [5, 10, 15, 20]

# %%
print(listA)
# Out:
# [5, 10, 15, 20]

# %%
type(listA)
# Out:
# list

# %%
print(listA[2])
# Out:
# 15

# %%
listA[2] = 150

# %%
print(listA)
# Out:
# [5, 10, 150, 20]
