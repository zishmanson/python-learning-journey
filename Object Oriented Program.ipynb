# %%
class Dog():
    def __init__(self, name,age):
        self.name = name
        self.age = age

    def bark(self):
        print("Woof Woof!")

# %%
fido = Dog("Fido", 2)

# %%
fido.bark()
# Out:
# Woof Woof!

# %%
print(fido.name)
# Out:
# Fido

# %%
print(fido.age)
# Out:
# 2
