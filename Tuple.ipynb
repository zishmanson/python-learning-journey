# %%
child1_birth = ("Julia", "Lucile Packard Childern's Hospital", "Stanford", "California", " United States", "07/29/2019", "09:42")

# %%
child2_birth = ("Austin", "Washington Hospital", "California", "United States", "07/28/2019", "16:25")

# %%
type(child1_birth)
# Out:
# tuple

# %%
type(child2_birth)
# Out:
# tuple

# %%
print(child1_birth)
# Out:
# ('Julia', "Lucile Packard Childern's Hospital", 'Stanford', 'California', ' United States', '07/29/2019', '09:42')

# %%
print(child2_birth)
# Out:
# ('Austin', 'Washington Hospital', 'California', 'United States', '07/28/2019', '16:25')

# %%
print(child1_birth[0])
# Out:
# Julia

# %%
#second child's time of birth

print(child2_birth[5])
# Out:
# 16:25
