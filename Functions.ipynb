# %%
print ("hello World")
# Out:
# hello World

# %%
name = input ("what is your name?")
color = input ("what is your favourite color?")
# Out:
# what is your name? zish
# what is your favourite color? blue

# %%
print (name)
# Out:
# zish

# %%
print (color)
# Out:
# blue

# %%
print("hi", name + "!", "your favourite color is", color + ".")
# Out:
# hi zish! your favourite color is blue.

# %%
def addfive(x):
        print (5 + x)

# %%
addfive(30)
# Out:
# 35

# %%
def greeting():
    print("Hey There")

# %%
greeting()
# Out:
# Hey There

# %%
def greet(name):
    print("Hi", name + "!")

# %%
greet("Zeeshan")
# Out:
# Hi Zeeshan!

# %%
def square(x):
    return x * x

# %%
result = square(5)

# %%
print(result)
# Out:
# 25

# %%
def sumofsquare(x, y):
    square1 = x * x
    square2 = y * y
    return square1 + square2

# %%
result = sumofsquares(2, 3)

# %%
print(result)
# Out:
# 25
