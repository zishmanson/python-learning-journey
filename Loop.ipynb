# %%
number=input("Enter any number:")
your_number = int(number)

total = 0
for num in range(your_number):
    total += num
print(total)
# Out:
# Enter any number: 200
# 19900

# %%
command = ''

while command.lower() != 'quit':
    command = input('>')
    print(f"Echo: {command}")
# Out:
# > Hi
# Echo: Hi
# > Zeeshan
# Echo: Zeeshan
# > quit
# Echo: quit
